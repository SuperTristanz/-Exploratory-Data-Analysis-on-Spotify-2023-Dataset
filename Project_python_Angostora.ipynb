# %% [markdown]
# # Project on Exploratory Data Analysis ( Most Streamed Spotify Songs 2023 )
# ####  (https://www.kaggle.com/datasets/nelgiriyewithana/top-spotify-songs-2023).
#
# ### Author: Angostora, Tristan Zeth V.
# ### Section: 2ECE-D

# %% [markdown]
# #### Importing the Libraries that will be used for the Said Project

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Reading the File Obtained from Kaggle

# %%
df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# ## Overview of Dataset

# %% [markdown]
# #### Getting the Number of Rows and Columns

# %%
columns, rows = df.shape
print('The Number of Columns: ', str(columns))
print('The Number of Rows: ', str(rows))
# Out:
# The Number of Columns:  953
# The Number of Rows:  24

# %% [markdown]
# #### Getting all the Dtypes and Missing Values

# %%
data= pd.DataFrame(df.dtypes, columns=['Data Type']).reset_index()
data.columns = ['Column Name', 'Data Type']

missing_values = df.isnull().sum().reset_index()
missing_values.columns = ['Column Name', 'Missing Count']

summary_1= data.merge(missing_counts)
summary_1
# Out:
#              Column Name Data Type  Missing Count
# 0             track_name    object              0
# 1         artist(s)_name    object              0
# 2           artist_count     int64              0
# 3          released_year     int64              0
# 4         released_month     int64              0
# 5           released_day     int64              0
# 6   in_spotify_playlists     int64              0
# 7      in_spotify_charts     int64              0
# 8                streams   float64              0
# 9     in_apple_playlists     int64              0
# 10       in_apple_charts     int64              0
# 11   in_deezer_playlists    object              0
# 12      in_deezer_charts     int64              0
# 13      in_shazam_charts    object             50
# 14                   bpm     int64              0
# 15                   key    object             95
# 16                  mode    object              0
# 17        danceability_%     int64              0
# 18             valence_%     int64              0
# 19              energy_%     int64              0
# 20        acousticness_%     int64              0
# 21    instrumentalness_%     int64              0
# 22            liveness_%     int64              0
# 23         speechiness_%     int64              0

# %% [markdown]
# ## Basic Descriptive Statistics

# %% [markdown]
# #### Getting the Mean, Median, and Standard Deviation of the Streams Column

# %%
mean = df['streams'].mean()
median = df['streams'].median()
std = df['streams'].std()

summary_2= pd.DataFrame({'Variable': ['Mean', 'Median', 'Standard Deviation'],'Value': [mean, median, std]})

summary_2
# Out:
#              Variable         Value
# 0                Mean  5.141374e+08
# 1              Median  2.905309e+08
# 2  Standard Deviation  5.668569e+08

# %%
plt.figure(figsize=(5, 5))

plt.bar(summary_2['Variable'], summary_2['Value'])

plt.title('Streams (Mean, Median, Mode)', fontsize = 16)
plt.xlabel('Variable', fontsize = 14)
plt.ylabel('Value', fontsize = 14)

plt.show()

# %% [markdown]
# #### What is the distribution of released_year and artist_count

# %%
plt.figure(figsize=(14, 6))

plt.subplot(2, 2, 1)
plt.hist(df['released_year'], edgecolor='black')
plt.title('Distribution of Released Year', fontsize=16)
plt.xlabel('Released Year', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Box plot for artist_count (vertical)
plt.subplot(2, 2, 2)
plt.boxplot(df['artist_count'], vert=True, patch_artist=True)
plt.title('Box Plot of Artist Count', fontsize=16)
plt.ylabel('Artist Count', fontsize=14)

plt.show()

# %% [markdown]
# #### Determining The Outliers

# %%
Q1 = df['artist_count'].quantile(0.25)
Q3 = df['artist_count'].quantile(0.75)
iden = Q3 - Q1

low = Q1-1.5*iden
up = Q3+1.5*iden 
outliers = df[(df['artist_count'] < low) | (df['artist_count'] > up)]

summary_3 = outliers[['track_name', 'artist(s)_name', 'artist_count']].sort_values('artist_count').reset_index(drop=True)
summary_3
# Out:
#                                            track_name  \
# 0                                     Tubarï¿½ï¿½o Te
# 1                 La Llevo Al Cielo (Ft. ï¿½ï¿½engo F
# 2                                    Cash In Cash Out
# 3                                sentaDONA (Remix) s2
# 4   Friday (feat. Mufasa & Hypeman) - Dopamine Re-...
# 5               OUT OUT (feat. Charli XCX & Saweetie)
# 6           Entre Nosotros (Remix) [con Nicki Nicole]
# 7   Stay With Me (with Justin Timberlake, Halsey, ...
# 8                            Happy Xmas (War Is Over)
# 9                                          BABY OTAKU
# 10  Annihilate (Spider-Man: Across the Spider-Vers...
# 11                                    POLARIS - Remix
# 12  Enemy (with JID) - from the series Arcane Leag...
# 13                                      Novo Balanï¿½
# 14  Calling (Spider-Man: Across the Spider-Verse) ...
# 15                                   Marisola - Remix
# 16  Link Up (Metro Boomin & Don Toliver, Wizkid fe...
# 17  Angel Pt 1 (feat. Jimin of BTS, JVKE & Muni Long)
# 18        Tere Vaaste (From "Zara Hatke Zara Bachke")
# 19                                   ULTRA SOLO REMIX
# 20                                  Jhoome Jo Pathaan
# 21                     Besharam Rang (From "Pathaan")
# 22                 Nobody Like U - From "Turning Red"
# 23                          We Don't Talk About Bruno
# 24  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# 25                                           Se Le Ve
# 26                                    Los del Espacio
#
#                                        artist(s)_name  artist_count
# 0      Dj LK da Escï¿½ï¿½cia, Tchakabum, mc jhenny, M             4
# 1   Nengo Flow, Anuel Aa, Chris Jedi, Chencho Corl...             4
# 2    Pharrell Williams, Tyler, The Creator, 21 Savage             4
# 3   Luï¿½ï¿½sa Sonza, MC Frog, Dj Gabriel do Borel...             4
# 4    Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine             4
# 5         Charli XCX, Jax Jones, Joel Corry, Saweetie             4
# 6   Lit Killah, Maria Becerra, Tiago pzk, NICKI NI...             4
# 7   Calvin Harris, Halsey, Pharrell Williams, Just...             4
# 8   John Lennon, The Harlem Community Choir, The P...             4
# 9   Fran C, Polima WestCoast, Nickoog Clk, Pablito...             4
# 10          Swae Lee, Lil Wayne, Offset, Metro Boomin             4
# 11                         Feid, Mora, Saiko, Quevedo             4
# 12    Imagine Dragons, League of Legends, JID, Arcane             4
# 13       Veigh, Bvga Beatz, Supernova Ent, Prod Malax             4
# 14  Swae Lee, A Boogie Wit da Hoodie, Metro Boomin...             4
# 15  Duki, NICKI NICOLE, Cris Mj, Standly, Stars Mu...             5
# 16     WizKid, Toian, Metro Boomin, Don Toliver, Beam             5
# 17    Kodak Black, NLE Choppa, Muni Long, JVKE, Jimin             5
# 18  Sachin-Jigar, Shadab Faridi, Altamash Faridi, ...             5
# 19  De La Ghetto, Feid, Polima WestCoast, Paloma M...             5
# 20  Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...             6
# 21  Vishal-Shekhar, Shilpa Rao, Caralisa Monteiro,...             6
# 22  Jordan Fisher, Josh Levi, Finneas O'Connell, 4...             6
# 23  Adassa, Mauro Castillo, Stephanie Beatriz, Enc...             7
# 24  Quevedo, La Pantera, Juseph, Cruz Cafunï¿½ï¿½,...             7
# 25  Arcangel, De La Ghetto, Justin Quiles, Lenny T...             8
# 26  Big One, Duki, Lit Killah, Maria Becerra, FMK,...             8

# %%
# Out:
#     index                                         track_name  \
# 0      35                                    Los del Espacio
# 1     135  Calling (Spider-Man: Across the Spider-Verse) ...
# 2     137        Tere Vaaste (From "Zara Hatke Zara Bachke")
# 3     141                                      Novo Balanï¿½
# 4     197                                    POLARIS - Remix
# 5     200  Annihilate (Spider-Man: Across the Spider-Vers...
# 6     201  Angel Pt 1 (feat. Jimin of BTS, JVKE & Muni Long)
# 7     238  Link Up (Metro Boomin & Don Toliver, Wizkid fe...
# 8     328                                   Marisola - Remix
# 9     365  Enemy (with JID) - from the series Arcane Leag...
# 10    393                                  Jhoome Jo Pathaan
# 11    402                     Besharam Rang (From "Pathaan")
# 12    457                           Happy Xmas (War Is Over)
# 13    488                                    Tubarï¿½ï¿½o Te
# 14    506                          We Don't Talk About Bruno
# 15    540          Entre Nosotros (Remix) [con Nicki Nicole]
# 16    605              OUT OUT (feat. Charli XCX & Saweetie)
# 17    638  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...
# 18    642                                           Se Le Ve
# 19    667  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# 20    749                               sentaDONA (Remix) s2
# 21    759                 Nobody Like U - From "Turning Red"
# 22    833                                   Cash In Cash Out
# 23    837                La Llevo Al Cielo (Ft. ï¿½ï¿½engo F
# 24    864                                   ULTRA SOLO REMIX
# 25    894  Stay With Me (with Justin Timberlake, Halsey, ...
# 26    920                                         BABY OTAKU
#
#                                        artist(s)_name  artist_count
# 0   Big One, Duki, Lit Killah, Maria Becerra, FMK,...             8
# 1   Swae Lee, A Boogie Wit da Hoodie, Metro Boomin...             4
# 2   Sachin-Jigar, Shadab Faridi, Altamash Faridi, ...             5
# 3        Veigh, Bvga Beatz, Supernova Ent, Prod Malax             4
# 4                          Feid, Mora, Saiko, Quevedo             4
# 5           Swae Lee, Lil Wayne, Offset, Metro Boomin             4
# 6     Kodak Black, NLE Choppa, Muni Long, JVKE, Jimin             5
# 7      WizKid, Toian, Metro Boomin, Don Toliver, Beam             5
# 8   Duki, NICKI NICOLE, Cris Mj, Standly, Stars Mu...             5
# 9     Imagine Dragons, League of Legends, JID, Arcane             4
# 10  Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...             6
# 11  Vishal-Shekhar, Shilpa Rao, Caralisa Monteiro,...             6
# 12  John Lennon, The Harlem Community Choir, The P...             4
# 13     Dj LK da Escï¿½ï¿½cia, Tchakabum, mc jhenny, M             4
# 14  Adassa, Mauro Castillo, Stephanie Beatriz, Enc...             7
# 15  Lit Killah, Maria Becerra, Tiago pzk, NICKI NI...             4
# 16        Charli XCX, Jax Jones, Joel Corry, Saweetie             4
# 17   Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine             4
# 18  Arcangel, De La Ghetto, Justin Quiles, Lenny T...             8
# 19  Quevedo, La Pantera, Juseph, Cruz Cafunï¿½ï¿½,...             7
# 20  Luï¿½ï¿½sa Sonza, MC Frog, Dj Gabriel do Borel...             4
# 21  Jordan Fisher, Josh Levi, Finneas O'Connell, 4...             6
# 22   Pharrell Williams, Tyler, The Creator, 21 Savage             4
# 23  Nengo Flow, Anuel Aa, Chris Jedi, Chencho Corl...             4
# 24  De La Ghetto, Feid, Polima WestCoast, Paloma M...             5
# 25  Calvin Harris, Halsey, Pharrell Williams, Just...             4
# 26  Fran C, Polima WestCoast, Nickoog Clk, Pablito...             4

# %% [markdown]
# ## Top Performers

# %% [markdown]
# #### Top 5 Most Streamed

# %%
top = df[['track_name', 'artist(s)_name', 'streams']].sort_values('streams', ascending=False).head().reset_index(drop=True)
top
# Out:
#                                       track_name         artist(s)_name  \
# 0                                Blinding Lights             The Weeknd
# 1                                   Shape of You             Ed Sheeran
# 2                              Someone You Loved          Lewis Capaldi
# 3                                   Dance Monkey            Tones and I
# 4  Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
#
#         streams
# 0  3.703895e+09
# 1  3.562544e+09
# 2  2.887242e+09
# 3  2.864792e+09
# 4  2.808097e+09

# %%
plt.figure(figsize=(20, 5))
plt.bar(top_streamed_summary['track_name'], top_streamed_summary['streams'])

plt.xlabel('Name of the Track')
plt.ylabel('Number of Steams in terms of 10x10^9')
plt.title('Top 5 Most Streamed Tracks')

plt.show()

# %% [markdown]
# #### Top 5 most frequent Artists based on the Number of Tracks

# %%
Tartist = df['artist(s)_name'].value_counts().head().reset_index()
Tartist.columns = ['artist(s)_name', 'track_count']
Tartist
# Out:
#   artist(s)_name  track_count
# 0   Taylor Swift           34
# 1     The Weeknd           22
# 2      Bad Bunny           19
# 3            SZA           19
# 4   Harry Styles           17

# %%
plt.figure(figsize=(10, 6))
plt.bar(Tartist['artist(s)_name'], Tartist['track_count'])

plt.xlabel('Artist Name')
plt.ylabel('Number of Tracks Produced')
plt.title('Top 5 Most Frequent Artists')

plt.show()

# %% [markdown]
# ## Temporal Trends

# %% [markdown]
# #### Trends in the Number of Tracks Released Over Time.

# %%
track= df['released_year'].value_counts().sort_index().reset_index()
track.columns = ['released_year', 'track_count']
track.set_index('released_year')
# Out:
#                track_count
# released_year
# 1930                     1
# 1942                     1
# 1946                     1
# 1950                     1
# 1952                     1
# 1957                     2
# 1958                     3
# 1959                     2
# 1963                     3
# 1968                     1
# 1970                     2
# 1971                     1
# 1973                     1
# 1975                     2
# 1979                     1
# 1982                     2
# 1983                     1
# 1984                     4
# 1985                     2
# 1986                     2
# 1987                     1
# 1991                     2
# 1992                     1
# 1994                     1
# 1995                     2
# 1996                     1
# 1997                     1
# 1998                     1
# 1999                     5
# 2000                     4
# 2002                     6
# 2003                     2
# 2004                     4
# 2005                     1
# 2007                     1
# 2008                     2
# 2010                     7
# 2011                    10
# 2012                    10
# 2013                    13
# 2014                    13
# 2015                    11
# 2016                    18
# 2017                    23
# 2018                    10
# 2019                    36
# 2020                    37
# 2021                   119
# 2022                   402
# 2023                   175

# %%
plt.figure(figsize=(15, 5))
plt.plot(track.index, track['track_count'], marker='o')
plt.xlabel('Years')
plt.ylabel('Tracks Released')
plt.title('Tracks Released in Passing Years')
plt.show()

# %% [markdown]
# #### Number of Tracks Released per Month

# %%
df.groupby("released_month")["released_month"].count()
# Out:
# released_month
# 1     134
# 2      61
# 3      86
# 4      66
# 5     128
# 6      86
# 7      62
# 8      46
# 9      56
# 10     73
# 11     80
# 12     75
# Name: released_month, dtype: int64

# %%
months = ["January", "Febuary", "March", "April", "May", "June", "July", "August", "September", "October","November","December"]
x = pd.Series(months)
y = df.groupby("released_month")["released_month"].count().tolist()

plt.figure(figsize=(20, 6))
plt.bar(x,y)
plt.xlabel('Months')
plt.ylabel('Tracks')
plt.title('Tracks released on each month')
plt.show()

# %% [markdown]
# ## Genre and Music Characteristics

# %% [markdown]
# #### Correlation between Streams and Musical attributes

# %%
M_at = ['bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%', 'streams']
for ats in M_at:
    df[ats] = pd.to_numeric(df[ats], errors='coerce')
    
cor_res = {}

for ats in M_at[:-1]: 
    cor_res[ats + ' vs Streams'] = df[ats].corr(df['streams'])
    
cor_d = pd.DataFrame(cor_res.items(), columns=['Attribute', 'Correlation Coefficient'])
cor_d
# Out:
#                        Attribute  Correlation Coefficient
# 0                 bpm vs Streams                -0.002438
# 1                 key vs Streams                 0.007695
# 2                mode vs Streams                 0.042635
# 3      danceability_% vs Streams                -0.105457
# 4           valence_% vs Streams                -0.040831
# 5            energy_% vs Streams                -0.026051
# 6      acousticness_% vs Streams                -0.004485
# 7  instrumentalness_% vs Streams                -0.044902
# 8          liveness_% vs Streams                -0.048337
# 9       speechiness_% vs Streams                -0.112333

# %%
plt.figure(figsize=(30, 5))
plt.plot(cor_d['Attribute'], cor_d['Correlation Coefficient'], marker='o')
plt.xlabel('Attributes', fontsize = 25)
plt.ylabel('Coefficient', fontsize = 25)
plt.title('Correlation the Coefficien and Attributes', fontsize = 30)
plt.show()

# %% [markdown]
# #### correlation between Danceability and Energy How about Valence and Acousticness

# %%
atib = ['danceability_%', 'energy_%', 'valence_%', 'acousticness_%']
for attr in atib:
    df[attr] = pd.to_numeric(df[attr], errors='coerce')
    
corr1 = df['danceability_%'].corr(df['energy_%'])
corr2 = df['valence_%'].corr(df['acousticness_%'])
corres = {'Danceability vs Energy': corr1,'Valence vs Acousticness': corr2}
rescor = pd.DataFrame(corres, index=['Correlation Coefficient']).T
rescor
# Out:
#                          Correlation Coefficient
# Danceability vs Energy                  0.198095
# Valence vs Acousticness                -0.081907

# %% [markdown]
# ## Platform Popularity

# %% [markdown]
# #### Which platform seems to favor the most popular tracks

# %%
count1 = df['in_spotify_playlists'].sum()
count2= df['in_spotify_charts'].sum()
count3= df['in_apple_playlists'].sum()
plat_res = pd.DataFrame({'platform': ['in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists'], 'track_count': [count1, count2, count3]})
plat_res
# Out:
#                platform  track_count
# 0  in_spotify_playlists      4955719
# 1     in_spotify_charts        11445
# 2    in_apple_playlists        64625

# %%
plt.figure(figsize=(10, 5))
plt.bar(plat_res['platform'], plat_res['track_count'])
plt.xlabel('Music Platforms')
plt.ylabel('Count (in terms of 10x10^6)')
plt.title('Track Counts in Different Platforms')
plt.show()

# %% [markdown]
# ##  Advanced Analysis

# %% [markdown]
# #### Major vs. Minor

# %%
counts= df.groupby(['key', 'mode']).size().reset_index(name='track_count')
counts
# Out:
#    key   mode  track_count
# 0    A  Major           42
# 1    A  Minor           33
# 2   A#  Major           27
# 3   A#  Minor           30
# 4    B  Major           35
# 5    B  Minor           46
# 6   C#  Major           73
# 7   C#  Minor           47
# 8    D  Major           66
# 9    D  Minor           15
# 10  D#  Major           12
# 11  D#  Minor           21
# 12   E  Major           17
# 13   E  Minor           45
# 14   F  Major           44
# 15   F  Minor           45
# 16  F#  Major           30
# 17  F#  Minor           43
# 18   G  Major           66
# 19   G  Minor           30
# 20  G#  Major           63
# 21  G#  Minor           28

# %%
key_counts = counts.groupby('key')['track_count'].sum()
plt.figure(figsize=(10, 10))
plt.pie(key_counts, labels=key_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Tracks by Key')
plt.show()

# %%
Mtotal= key_mode_counts.groupby('mode')['track_count'].sum().reset_index()
Mtotal
# Out:
#     mode  track_count
# 0  Major          475
# 1  Minor          383

# %%
mode_counts = counts.groupby('mode')['track_count'].sum()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(mode_counts, labels=mode_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Tracks by Mode (Major vs. Minor)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# #### Artists consistently appear in more playlists or charts

# %%
artist_playlist_counts = df.groupby('artist(s)_name')['in_spotify_playlists'].sum().reset_index()
artist_chart_counts = df.groupby('artist(s)_name')['in_spotify_charts'].sum().reset_index()
artist_apple_counts = df.groupby('artist(s)_name')['in_apple_playlists'].sum().reset_index()

artist_counts = (
    artist_playlist_counts.merge(artist_chart_counts, on='artist(s)_name', suffixes=('_playlists', '_charts')).merge(artist_apple_counts, on='artist(s)_name'))
artist_counts.rename(columns={'in_apple_playlists': 'in_apple_playlists'}, inplace=True)
top_artists = artist_counts.sort_values(by='in_spotify_playlists', ascending=False).head(10)
top_artists.reset_index()
# Out:
#    index       artist(s)_name  in_spotify_playlists  in_spotify_charts  \
# 0    572           The Weeknd                144053                180
# 1    558         Taylor Swift                132974                542
# 2    159           Ed Sheeran                128758                 94
# 3    223         Harry Styles                110026                185
# 4    171               Eminem                 87331                152
# 5     25       Arctic Monkeys                 84016                190
# 6    111             Coldplay                 75716                 72
# 7     33               Avicii                 68241                 42
# 8    141  Dr. Dre, Snoop Dogg                 65728                  0
# 9      7                Adele                 65049                 69
#
#    in_apple_playlists
# 0                1677
# 1                1796
# 2                1448
# 3                1741
# 4                 475
# 5                 241
# 6                 381
# 7                 407
# 8                 283
# 9                 646

# %%
artist_playlist_counts = df.groupby('artist(s)_name')['in_spotify_playlists'].sum().reset_index()
artist_chart_counts = df.groupby('artist(s)_name')['in_spotify_charts'].sum().reset_index()
artist_apple_counts = df.groupby('artist(s)_name')['in_apple_playlists'].sum().reset_index()

artist_counts = (artist_playlist_counts.merge(artist_chart_counts, on='artist(s)_name', suffixes=('_playlists', '_charts')).merge(artist_apple_counts, on='artist(s)_name'))

top_artists_playlists = artist_counts.sort_values(by='in_spotify_playlists', ascending=False).head(10)
top_artists_charts = artist_counts.sort_values(by='in_spotify_charts', ascending=False).head(10)
top_artists_apple = artist_counts.sort_values(by='in_apple_playlists', ascending=False).head(10)

top_artists_playlists.set_index('artist(s)_name', inplace=True)
top_artists_charts.set_index('artist(s)_name', inplace=True)
top_artists_apple.set_index('artist(s)_name', inplace=True)

fig, axs = plt.subplots(3, 1, figsize=(12, 18))
top_artists_playlists['in_spotify_playlists'].plot(kind='bar', ax=axs[0], color='skyblue')
axs[0].set_title('Top 10 Artists by Number of Tracks in Spotify Playlists')
axs[0].set_ylabel('Track Count')
axs[0].set_xticklabels(top_artists_playlists.index, rotation=0) 

top_artists_charts['in_spotify_charts'].plot(kind='bar', ax=axs[1], color='lightgreen')
axs[1].set_title('Top 10 Artists by Number of Tracks in Spotify Charts')
axs[1].set_ylabel('Track Count')
axs[1].set_xticklabels(top_artists_charts.index, rotation=0) 

top_artists_apple['in_apple_playlists'].plot(kind='bar', ax=axs[2], color='salmon')
axs[2].set_title('Top 10 Artists by Number of Tracks in Apple Playlists')
axs[2].set_ylabel('Track Count')
axs[2].set_xticklabels(top_artists_apple.index, rotation=0)  

plt.show()
